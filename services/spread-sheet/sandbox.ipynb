# %%
from app.services.sql_service import SQLService

sql_service = SQLService()

query = f"""
                SELECT content, column_descriptions
                FROM gg_sheets
                """
sql_service.test_sql_query(query)
# Out:
# [(147868,
#   '{"Image rec": {"Part Type code ": "", "Note": "", "Max # of images": "", "Downloaded all": "", "01/21": "", "01/23": ""}, "VP scraping ": {"Scrape data ": ""}, "Daily report ": {"04/10": "", "": ""}, "Zoho": {"gerry@wholesalecarparts.com.au": "", "Wcp88rft%_11": ""}, "Alternate Index Search by alternate Index": {"Email": "", "": ""}, "Facebook bot": {"WCP AUS": "", "": ""}, "Part Types": {"partTypeCode": "", "partTypeFriendlyName": ""}, "OEM searching agent ": {"Id": "", "Part types ": "", "Date added": "", "": ""}, "OEM searching agent partsouq ": {"Id": "", "Part types ": "", "Date added": ""}, "PRT to Pinnacle automation ": {"Research ID": "", "Note ": ""}}'),
#  (147867,
# ...
